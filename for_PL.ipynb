# %% [markdown]
# # 2.1開始
# 使用pdfplumber套件讀取PL檔案名稱為"PSE_件號_PL"的pdf檔，並轉換成txt檔

# %%
import os
import pdfplumber

# 輸入和輸出資料夾的路徑
input_folder = r"_PL\pdf_file"  # 輸入資料夾的路徑
output_folder = r"_PL\pdf2txt"  # 輸出資料夾的路徑

# 確保輸出資料夾存在，如果不存在則創建它
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 列出輸入資料夾中符合條件的所有pdf檔案
pdf_files = [f for f in os.listdir(input_folder) if f.startswith('PSE_') and f.endswith('.pdf') and 'PL' in f]

# 儲存所有替換後的txt內容
all_texts = []

# 使用下面該函數把全形有空格的文字替換掉
def replace_multiple_texts(s):
    """
    一次性替換多個子字串
    """
    replacements = {
        'C O R P O R A T E': 'CORPORATE',
        'O F F I C E S': 'OFFICE',
        'N U M B E R': 'NUMBER',
        'R E V': 'REV',
        'S H E E T': 'SHEET',
        'B O E I N G': 'BOEING',
        'S E A T T L E': 'SETTLE',
        'W A': 'WA',
        '98 1 2 4': '98124',
        'L IS T': 'LIST',
        'T IT L E': 'TITLE',
        'M O D E L': 'MODEL',
        'C O N T R A C T': 'CONTRACT',
        'D A T E': 'DATE',
        'TL II TS LT E':'LIST TITLE',
        'S H T':'SHT',
        'INSTL':'ASSY'
    }
    
    for old, new in replacements.items():
        s = s.replace(old, new)
    
    return s

# 刪除只包含一個單詞的行
def remove_single_word_lines(text):
    """
    刪除只包含一個單詞的行
    """
    lines = text.split('\n')
    filtered_lines = [line for line in lines if len(line.split()) > 1]
    return '\n'.join(filtered_lines)

# 針對每一個PDF檔案
for pdf_file in pdf_files:
    input_path = os.path.join(input_folder, pdf_file)
    
    # 打開PDF檔案並提取文本
    with pdfplumber.open(input_path) as pdf:
        combined_text = ""
        
        # 從第3頁開始提取文本
        for page_number in range(1, len(pdf.pages)):
            page = pdf.pages[page_number]
            text = page.extract_text()
            
            # 替換文本中的多個子字串
            replaced_text = replace_multiple_texts(text)
            
            # 刪除只包含一個單詞的行
            filtered_text = remove_single_word_lines(replaced_text)
            
            # 組合所有頁面的文本
            combined_text += f"Page {page_number + 2}:\n{filtered_text}\n{'='*50}\n"
    
    all_texts.append(combined_text)
    
    # 從pdf檔案名稱中提取簡短的名稱作為輸出檔案名稱
    short_name = pdf_file.split('_')[1]
    
    # 寫入替換後的文本到輸出資料夾中
    output_path = os.path.join(output_folder, f"{short_name}.txt")
    with open(output_path, "w", encoding="utf-8") as text_file:
        text_file.write(combined_text)

# 印出完成訊息
print("Text extraction, replacing, and combining complete.")
# Out:
# Text extraction, replacing, and combining complete.

# %% [markdown]
# # 2.1 結束

# %% [markdown]
# # 2.2開始

# %% [markdown]
# 對轉換成txt檔的文件進行關鍵字(如件號、名稱、材質、規範)擷取並填入進去excel中

# %%
import os
import openpyxl
from openpyxl.styles import Alignment, PatternFill, Font

# 關鍵資訊擷取
def read_txt(filename):
    global pl, pl1, list_title, stock, per 
    pl = []
    pl1 = []
    list_title = []
    stock = []
    per = []


    with open(filename, 'r', encoding='utf-8') as file:
        stock_flag = 0
        pl_found = 0  # 新增一個 flag 來判斷是否已經找到 PL

        line = file.readlines()

        # 跳過第一行(因為第一行有 PL)  
        for content in line[1:]:
            # 將每一行中的每個單字分別拆開
            word = content.split()
            # 判斷 PL 是否在此行中
            if 'PARTS' == word[0]:
                # 取出位於 PL 之後的字串並存入 pl[]
                index = word.index('PL')
                pl = ' '.join(word[index+1:-1]).strip()
                pl_found = 1  # 設置 flag 為 True，表示已經找到 PL
                #print(pl)
                break  # 找到 PL 後就跳出迴圈
        # 如果找到了 PL，則執行後續的程式碼
        if pl_found:
            for content in line[11:-14]:
                word = content.split()
                first_char_is_digit = word[0][0].isdigit()
                last_char_is_alpha = word[-1][-1].isalpha()
                if (first_char_is_digit and last_char_is_alpha and len(word[0]) < 4 and 'PER' not in content and 'INFO' not in content and 'SECONDS' not in content) or \
                   (first_char_is_digit and 'MD' in content) or (first_char_is_digit and word[-1] == '-'and 'INFO' not in content and 'SECONDS' not in content) or \
                   (first_char_is_digit and word[1][-1].isalpha() and len(word[0]) < 4 and 'PER' not in content and 'INFO' not in content and 'SECONDS' not in content) or\
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][1:].isdigit() and word[-2]!='SHEET' and word[-1]!='PAGE)') or \
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][1:].isdigit() and word[-4]=='DRAWING') or \
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][-1].isalpha() and word[-2]!='SHEET' and word[-1]!='PAGE)'):
                    #取出位於ASSY或1後面的件號並存入pl1[]
                    index = index = word.index(word[0]) if first_char_is_digit else word.index('ASSY')
                    ass_ans = ' '.join(word[index + 1:index + 2]).strip()
                    pl1.append(ass_ans)
                    print(pl1)
                #判斷對應的件號名稱是否在此行中
                if (first_char_is_digit and last_char_is_alpha and len(word[0]) < 4 and 'PER' not in content and 'INFO' not in content and 'SECONDS' not in content) or \
                   (first_char_is_digit and 'MD' in content) or (first_char_is_digit and word[-1] == '-'and 'INFO' not in content and 'SECONDS' not in content) or \
                   (first_char_is_digit and word[1][-1].isalpha() and len(word[0]) < 4 and 'PER' not in content and 'INFO' not in content and 'SECONDS' not in content) or\
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][1:].isdigit() and word[-2]!='SHEET' and word[-1]!='PAGE)') or \
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][1:].isdigit() and word[-4]=='DRAWING') or \
                   ('ASSY' == word[0] and word[1][0] == '-' and word[1][-1].isalpha() and word[-2]!='SHEET' and word[-1]!='PAGE)'):
                    #取出位於件號到-之間的名稱存入list_title
                    index = word.index('-')
                    index2 = word.index(word[0]) if first_char_is_digit else word.index('ASSY')
                    list_title_ans = ' '.join(word[int(index2) +2:int(index)]).strip()
                    list_title.append(list_title_ans)
        # 找材質及規範
        line_number = 0
        start_line = None  # 起始行的索引
        for j in range(len(line)):
            line_number += 1
            words = line[j].split()  # 將行分割成單詞
            #因為材質及規範會對應到沒個件
            if (line[j][0].isdigit() and 'MD' in words and not any(word == 'PER' for word in words) and 'CHANGE' not in words and 'INFO' not in words) or \
               (line[j][0].isdigit() and '-' == line[j][-2] and not any(word == 'PER' for word in words) and 'CHANGE' not in words and 'INFO' not in words) or \
               (line[j][0].isdigit() and ('-' == line[j][2] or line[j][2].isalpha()) and not any(word == 'PER' for word in words) and 'CHANGE' not in words and 'INFO' not in words) or \
               (line[j][0].isdigit() and line[j][-1] == '-' and not any(word == 'PER' for word in words) and 'CHANGE' not in words and 'INFO' not in words) or\
               (line[j][0].isdigit() and line[j][-2][0].isalpha() and not any(word == 'PER' for word in words) and 'CHANGE' not in words and 'INFO' not in words and 'PAGE' not in words and 'VOLATILES' not in words and 'PRIOR' not in words and 'SECONDS' not in words)or\
               ('ASSY' == line[j][0:4] and 'DRAWING' in line[j]) or\
               ('ASSY' == line[j][0:4] and '(CONTINUED' not in line[j] and 'SHEET'not in line[j]):
                print(f"Condition triggered at line {line_number}")
                stock_flag = 1
                if stock_flag == 1:
                    if start_line is not None:
                        # 在起始行到結束行之間檢查是否包含 'STOCK' 或 'MAKE FROM'
                        found_stock = any('STOCK' in line[k] and 'PER' in line[k+1] for k in range(start_line, j + 1))
                        found_make_from = any('MAKE FROM' in line[k] for k in range(start_line, j))

                        if found_stock:
                            for k in range(start_line, j+1):
                                if 'STOCK' in line[k] and 'PER' in line[k+1]:
                                    index = line[k+1].find('PER')
                                    stock_ans = line[k+1][:index].strip()
                                    per_ans = line[k+1][index + len('PER'):].strip()
                                    stock.append(stock_ans)
                                    per.append(per_ans)
                                    start_line = None
                                    break
                                
                        elif found_make_from:
                            # 如果沒有找到 'STOCK' 但找到了 "MAKE FROM"，則將其後的文字存入 stock_ans
                            for k in range(start_line, j):
                                if 'MAKE FROM' in line[k]:
                                    index = line[k].find('FROM')
                                    stock_ans = line[k][index + len('FROM'):-2].strip()
                                    stock.append(stock_ans)
                                    per.append(" ")
                                    start_line = None  # 找到 "MAKE FROM" 後，重置標誌
                                    break
                        else:
                            # 如果起始行到結束行之間沒有找到 'STOCK' 或 "MAKE FROM"，則添加空白字符
                            stock.append(" ")
                            per.append(" ")

                    start_line = j  # 更新起始行的索引

        # 處理最後一次迴圈滿足條件後的所有行，直到文本的最後一行
        if start_line is not None and start_line < len(line) - 1:
            stock_found = False
            for k in range(start_line + 1, len(line)):
                if 'STOCK' in line[k]:
                    stock_found = True
                if stock_found and 'STOCK' in line[k] and 'PER' in line[k+1]:
                    index = line[k+1].find('PER')
                    stock_ans = line[k+1][:index].strip()
                    per_ans = line[k+1][index + len('PER'):].strip()
                    stock.append(stock_ans)
                    per.append(per_ans)
                    break
                elif stock_found and 'MAKE FROM' in line[k]:
                    index = line[k].find('FROM')
                    stock_ans = line[k][index + len('FROM'):-2].strip()
                    stock.append(" ")
                    per.append(" ")
                    break
            else:
                # 如果起始行到結束行之間沒有找到 'STOCK' 或 "MAKE FROM"，則添加空白字符
                stock.append(" ")
                per.append(" ")
        print(per)


# 將擷取到的關鍵資訊依照MBOM格式匯入EXCEL中
def creat_excel(output_folder, file_name):
    global stock, per, pl, pl1, list_title 

    workbook = openpyxl.Workbook()
    sheet = workbook.active

    #將B欄填入NO
    sheet.cell(row=1, column=2).value = 'NO'

    #將C~K欄填入0~8
    for col in range(3, 12):
        sheet.cell(row=1, column=col).value = col - 3
    
    # 將 pl[] 的值存入 excel 的 L 欄
    sheet.cell(row=1, column=12).value = '件號\nPart Number'
    for i in range(0, len(pl1)):
        if len(pl1[i]) < 6:  # 如果 pl1[i] 的長度小於 6
            sheet.cell(row=i+2, column=12).value = pl + pl1[i]
        else:
            sheet.cell(row=i+2, column=12).value = pl1[i]


    # 將 list_title[] 的值存入 excel 的 M 欄
    sheet.cell(row = 1, column = 13).value = '名稱\nNOMENCLA TURE'
    for i in range(0, len(list_title)):
        sheet.cell(row=i+2, column=13).value = list_title[i]
    
    # 將 N 欄的標題設置為 '類別\nCode'
    sheet.cell(row = 1, column = 14).value = '類別\nCode'
    
    # 將 O 欄的標題設置為 '零件代碼\nShape'
    sheet.cell(row = 1, column = 15).value = '零件代碼\nShape'

    # 將 stock[] 的值存入 excel 的 P 欄
    sheet.cell(row = 1, column = 16).value = '材質\nMaterial'
    for i in range(0, len(stock)):
        sheet.cell(row = i+2, column = 16).value = stock[i]

    # 將 per[] 的值存入 excel 的 Q 欄
    sheet.cell(row = 1, column = 17).value = '規範\nSpec.'
    for i in range(0, len(per)):
        sheet.cell(row = i+2, column = 17).value = per[i]
    
    #EXCEL排版設定
    target_row = 1
    last_col = sheet.max_column

    # 設置Alignment物件，指定水平置中和自動換行
    alignment = Alignment(horizontal='center', wrapText=True)

    # 遍歷指定行的每一列，並將文字設置為置中和自動換行
    for col in range(1, last_col + 1):
        cell = sheet.cell(row=target_row, column=col)
        cell.alignment = alignment
    
    #設定顏色與字形
    for col_index in range(1, last_col + 1):
        cell = sheet.cell(row=1, column=col_index)
        cell.fill = PatternFill(start_color="CCFFCC", end_color="CCFFCC", fill_type="solid")
    #設定字形
        if isinstance(cell.value, str) and any('\u4e00' <= char <= '\u9fff' for char in cell.value):
                font = Font(name='Malgun Gothic', color='000000', bold=False)  # 設定要的中文字體
        else:
            font = Font(name='Calibri', color='000000', bold=False)  # 設定要的英文字體
                
        cell.font = font
    
    # 設定欄寬
    columns_to_adjust = ['L', 'M', 'P', 'Q']
    default_column_width = 30
    columns_to_adjust_1 = ['N', 'O']
    default_column_width_1 = 10

    for col_letter in columns_to_adjust:
        sheet.column_dimensions[col_letter].width = default_column_width
    for col_letter in columns_to_adjust_1:
        sheet.column_dimensions[col_letter].width = default_column_width_1

    workbook.save(os.path.join(output_folder, f"{file_name}_output.xlsx"))


# 輸入目標資料夾路徑給 creat_excel 函式
def read_folder(input_folder, output_folder):
    global index
    index = 1
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.txt'):
            file_path = os.path.join(input_folder, file_name)
            read_txt(file_path)
            base_name = os.path.splitext(file_name)[0]
            creat_excel(output_folder, base_name)
            index += 1

# 修改這行以指定目標資料夾和輸出資料夾路徑
input_folder_path = r"_PL\pdf2txt"  
output_folder_path = r"_PL\final_output"
read_folder(input_folder_path, output_folder_path)
# Out:
# ['-1']
# ['-1', '284W1803-20']
# ['-1', '284W1803-20', '401T2801-3']
# ['-1', '284W1803-20', '401T2801-3', '-2']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2', '284W1803-2']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2', '284W1803-2', '401T2801-3']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2', '284W1803-2', '401T2801-3', '-4']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2', '284W1803-2', '401T2801-3', '-4', '284W1803-41']
# ['-1', '284W1803-20', '401T2801-3', '-2', '284T0383-2', '284W1803-1', '401T2801-3', '-3', '284T0383-2', '284W1803-2', '401T2801-3', '-4', '284W1803-41', '401T2801-3']
# Condition triggered at line 36
# Condition triggered at line 38
# Condition triggered at line 39
# Condition triggered at line 56
# Condition triggered at line 58
# Condition triggered at line 59
# Condition triggered at line 60
# Condition triggered at line 63
# Condition triggered at line 65
# Condition triggered at line 66
# Condition triggered at line 67
# Condition triggered at line 70
# Condition triggered at line 72
# Condition triggered at line 73
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['-1']
# ['-1', '-37']
# ['-1', '-37', 'NAS463YKDD416']
# ['-1', '-37', 'NAS463YKDD416', '-17']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42', 'BACN10JR3F']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42', 'BACN10JR3F', '-6']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42', 'BACN10JR3F', '-6', '-7']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42', 'BACN10JR3F', '-6', '-7', 'BACN10JR3F']
# ['-1', '-37', 'NAS463YKDD416', '-17', '-18', 'BACN10JR3F', '-2', '-21', 'NAS463YKDD416', '-25', '-26', 'NAS463YKDD416', '-32', '-33', 'NAS463YKDD416', '-41', '-42', 'BACN10JR3F', '-6', '-7', 'BACN10JR3F', 'BACN10KB3F']
# Condition triggered at line 415
# Condition triggered at line 417
# Condition triggered at line 423
# Condition triggered at line 425
# Condition triggered at line 428
# Condition triggered at line 434
# Condition triggered at line 450
# Condition triggered at line 453
# Condition triggered at line 459
# Condition triggered at line 461
# Condition triggered at line 464
# Condition triggered at line 471
# Condition triggered at line 473
# Condition triggered at line 476
# Condition triggered at line 483
# Condition triggered at line 499
# Condition triggered at line 503
# Condition triggered at line 509
# Condition triggered at line 511
# Condition triggered at line 514
# Condition triggered at line 520
# Condition triggered at line 521
# [' ', 'AMS 4347', ' ', ' ', 'AMS 4347', ' ', ' ', 'AMS 4347', ' ', ' ', 'AMS 4347', ' ', ' ', 'AMS 4347', ' ', ' ', 'AMS4347', ' ', ' ', 'AMS 4347', ' ', ' ']
# ['-12']
# ['-12', '-13']
# ['-12', '-13', '-2']
# ['-12', '-13', '-2', '-6']
# ['-12', '-13', '-2', '-6', '-9']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6', '-4']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6', '-4', 'MS20253P2-2575']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6', '-4', 'MS20253P2-2575', '-9']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6', '-4', 'MS20253P2-2575', '-9', '-7']
# ['-12', '-13', '-2', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-14', '-11', '-13', '-6', '-9', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-15', '-4', 'MS20253P2-2575', '-16', '-7', 'MS20253P2-5675', '-20', '-15', '-16', '-18', '-19', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-21', '-15', '-16', '-17', '-18', 'BACG20AA1', 'BACS21Y3W', 'BACS21Y5W', '-24', '-22', '-23', '284U2706-20', '284U2706-25', 'BACG20AA1', 'BACS21Y4W', 'BACS21Y6W', '-25', '284U2706-17', '284U2706-26', 'BACS21Y4R', '-26', '284U2706-27', '284U2706-29', '-6', '-4', 'MS20253P2-2575', '-9', '-7', 'MS20253P2-5675']
# Condition triggered at line 130
# Condition triggered at line 134
# Condition triggered at line 139
# Condition triggered at line 160
# Condition triggered at line 162
# Condition triggered at line 164
# Condition triggered at line 165
# Condition triggered at line 166
# Condition triggered at line 168
# Condition triggered at line 172
# Condition triggered at line 179
# Condition triggered at line 184
# Condition triggered at line 186
# Condition triggered at line 188
# Condition triggered at line 189
# Condition triggered at line 190
# Condition triggered at line 206
# Condition triggered at line 209
# Condition triggered at line 211
# Condition triggered at line 213
# Condition triggered at line 216
# Condition triggered at line 218
# Condition triggered at line 220
# Condition triggered at line 222
# Condition triggered at line 225
# Condition triggered at line 228
# Condition triggered at line 234
# Condition triggered at line 240
# Condition triggered at line 241
# Condition triggered at line 242
# Condition triggered at line 258
# Condition triggered at line 260
# Condition triggered at line 263
# Condition triggered at line 266
# Condition triggered at line 272
# Condition triggered at line 278
# Condition triggered at line 279
# Condition triggered at line 280
# Condition triggered at line 282
# Condition triggered at line 285
# Condition triggered at line 291
# Condition triggered at line 297
# Condition triggered at line 298
# Condition triggered at line 299
# Condition triggered at line 300
# Condition triggered at line 301
# Condition triggered at line 317
# Condition triggered at line 320
# Condition triggered at line 321
# Condition triggered at line 322
# Condition triggered at line 324
# Condition triggered at line 327
# Condition triggered at line 328
# Condition triggered at line 330
# Condition triggered at line 332
# Condition triggered at line 334
# Condition triggered at line 336
# Condition triggered at line 338
# Condition triggered at line 340
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['-18']
# ['-18', '-19']
# Condition triggered at line 160
# Condition triggered at line 162
# [' ', 'QQ-A-200/11']
# ['-11']
# ['-11', '-13']
# ['-11', '-13', 'BACN10JN3CD']
# ['-11', '-13', 'BACN10JN3CD', '-15']
# ['-11', '-13', 'BACN10JN3CD', '-15', '-16']
# ['-11', '-13', 'BACN10JN3CD', '-15', '-16', 'BACN10JN3CD']
# ['-11', '-13', 'BACN10JN3CD', '-15', '-16', 'BACN10JN3CD', '-24']
# ['-11', '-13', 'BACN10JN3CD', '-15', '-16', 'BACN10JN3CD', '-24', '-25']
# ['-11', '-13', 'BACN10JN3CD', '-15', '-16', 'BACN10JN3CD', '-24', '-25', 'BACB28AT09B013C']
# Condition triggered at line 281
# Condition triggered at line 285
# Condition triggered at line 292
# Condition triggered at line 294
# Condition triggered at line 297
# Condition triggered at line 303
# Condition triggered at line 319
# Condition triggered at line 322
# Condition triggered at line 329
# [' ', 'AMS4347.', ' ', ' ', 'QQ-A-250/4.', ' ', ' ', 'QQ-A-250/12', ' ']
# []
# []
# ['-11']
# ['-11', '-12']
# ['-11', '-12', 'BACN10JN3']
# ['-11', '-12', 'BACN10JN3', '-20']
# ['-11', '-12', 'BACN10JN3', '-20', '-18']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4', '-5']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4', '-5', 'BACN10JN3']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4', '-5', 'BACN10JN3', '-6']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4', '-5', 'BACN10JN3', '-6', '-7']
# ['-11', '-12', 'BACN10JN3', '-20', '-18', 'MS20253P2-2175', '-24', '-22', 'MS20253P2-5375', '-25', '-22', 'MS20253P2-5375', '-4', '-5', 'BACN10JN3', '-6', '-7', 'BACN10JN3']
# Condition triggered at line 210
# Condition triggered at line 212
# Condition triggered at line 215
# Condition triggered at line 217
# Condition triggered at line 219
# Condition triggered at line 221
# Condition triggered at line 223
# Condition triggered at line 226
# Condition triggered at line 228
# Condition triggered at line 230
# Condition triggered at line 233
# Condition triggered at line 235
# Condition triggered at line 237
# Condition triggered at line 239
# Condition triggered at line 243
# Condition triggered at line 259
# Condition triggered at line 261
# Condition triggered at line 265
# [' ', '-OQ-A-200/3', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'QQ-A-200/3', ' ', ' ', 'QQ-A-200/3', ' ']
# []
# ['-10']
# ['-10', '-21']
# ['-10', '-21', '232W2233-1']
# ['-10', '-21', '232W2233-1', '-11A']
# ['-10', '-21', '232W2233-1', '-11A', '-22A']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18', 'BACN10JR3CFD']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18', 'BACN10JR3CFD', 'BACN10JR4CFD']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18', 'BACN10JR3CFD', 'BACN10JR4CFD', 'BACN10TL3-14']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18', 'BACN10JR3CFD', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3']
# ['-10', '-21', '232W2233-1', '-11A', '-22A', '232W2233-2', '232W2233-3', '-23', '-24', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2', '-7', '-18', 'BACN10JR3CFD', 'BACN10JR4CFD', 'BACN10TL3-14', 'BACN10TL3-3', 'BACS53B1EA2']
# Condition triggered at line 72
# Condition triggered at line 73
# Condition triggered at line 176
# Condition triggered at line 180
# Condition triggered at line 186
# Condition triggered at line 202
# Condition triggered at line 206
# Condition triggered at line 213
# Condition triggered at line 214
# Condition triggered at line 216
# Condition triggered at line 220
# Condition triggered at line 227
# Condition triggered at line 228
# Condition triggered at line 229
# Condition triggered at line 230
# Condition triggered at line 246
# Condition triggered at line 250
# Condition triggered at line 257
# Condition triggered at line 258
# Condition triggered at line 259
# Condition triggered at line 260
# Condition triggered at line 261
# [' ', 'QQ-A-200/11', ' ', 'QQ-A-200/11', ' ', ' ', 'QQ-A-200/11', ' ', ' ', ' ', 'QQ-A-200/11', ' ', ' ', ' ', ' ', ' ', 'QQ-A-200/11', ' ', ' ', ' ', ' ', ' ']
# []
# ['-1']
# ['-1', '-2']
# ['-1', '-2', 'AS1716D40']
# ['-1', '-2', 'AS1716D40', '-10']
# ['-1', '-2', 'AS1716D40', '-10', '-6']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7', '-10']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7', '-10', 'AS1732D40']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7', '-10', 'AS1732D40', '-9']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7', '-10', 'AS1732D40', '-9', '-11']
# ['-1', '-2', 'AS1716D40', '-10', '-6', '-9', '-3', '-4', 'AS1716D40', '-5', '-8', 'AS1716D40', 'AS1737D40', '-7', '-10', 'AS1732D40', '-9', '-11', 'MS21209C0410P']
# Condition triggered at line 80
# Condition triggered at line 84
# Condition triggered at line 88
# Condition triggered at line 104
# Condition triggered at line 106
# Condition triggered at line 110
# Condition triggered at line 113
# Condition triggered at line 117
# Condition triggered at line 122
# Condition triggered at line 124
# Condition triggered at line 128
# Condition triggered at line 136
# Condition triggered at line 137
# Condition triggered at line 153
# Condition triggered at line 157
# Condition triggered at line 159
# Condition triggered at line 161
# Condition triggered at line 163
# Condition triggered at line 167
# [' ', ' ', ' ', ' ', 'WW-T-700/3', ' ', ' ', 'WW-T-700/6', ' ', ' ', 'WW-T-700/6', ' ', ' ', ' ', ' ', ' ', ' ', 'QQ-A-200/3', ' ']
# ['-1']
# ['-1', '-3']
# ['-1', '-3', '-4']
# ['-1', '-3', '-4', 'MS20427M4C5']
# Condition triggered at line 70
# Condition triggered at line 73
# Condition triggered at line 78
# Condition triggered at line 83
# [' ', 'AMS 5901, ANNEALED', 'AMS 5901, ANNEALED', ' ']
# []
# ['-1A']
# ['-1A', '-101A']
# ['-1A', '-101A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32', '-82']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32', '-82', 'BACN10YD1']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32', '-82', 'BACN10YD1', '-4A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32', '-82', 'BACN10YD1', '-4A', '-104A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-111', '-109', 'BACN10JP3A', '-112', '-110', 'BACN10JP3A', '-115', '-113', 'BACN10JP3A', '-116', '-114', 'BACN10JP3A', '-119', '-117', 'BACN10JP3A', '-120', '-118', 'BACN10JP3A', '-123', '-121', 'BACN10JP3A', '-124', '-122', 'BACN10JP3A', '-2A', '-102A', 'BACN10JR3CFD', '-21', '-77', 'BACN10YD1', '-25', '-75', 'BACN10YD1', '-29', '-79', 'BACN10JP3A', '-3A', '-103A', 'BACN10JR3CFD', '-30', '-80', 'BACN10JP3A', '-31', '-81', 'BACN10YD1', '-32', '-82', 'BACN10YD1', '-4A', '-104A', 'BACN10JR3CFD']
# ...
# ['-113']
# Condition triggered at line 14382
# Condition triggered at line 14416
# [' ', ' ']
# ['-1']
# ['-1', '-11']
# ['-1', '-11', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1', 'BACN10KA3CCM']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1', 'BACN10KA3CCM', '-7']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1', 'BACN10KA3CCM', '-7', '-10']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1', 'BACN10KA3CCM', '-7', '-10', '218T1402-2']
# ['-1', '-11', '218T1402-1', 'BACN10KA3CCM', '-15', '-16', '218T1402-2', 'BACN10KA3CCM', '-17', '-18', '218T1402-1', 'BACN10KA3CCM', '-2', '-12', '218T1402-1', 'BACN10KA3CCM', '-3', '-13', '218T1402-2', 'BACN10KA3CCM', '-4', '-14', '218T1402-1', '218T1407-5', 'BACN10KA3CCM', '-5', '-8', '218T1402-1', 'BACN10KA3CCM', '-6', '-9', '218T1402-1', 'BACN10KA3CCM', '-7', '-10', '218T1402-2', 'BACN10KA3CCM']
# Condition triggered at line 81
# Condition triggered at line 83
# Condition triggered at line 87
# Condition triggered at line 88
# Condition triggered at line 104
# Condition triggered at line 107
# Condition triggered at line 112
# Condition triggered at line 113
# Condition triggered at line 115
# Condition triggered at line 116
# Condition triggered at line 121
# Condition triggered at line 122
# Condition triggered at line 124
# Condition triggered at line 126
# Condition triggered at line 130
# Condition triggered at line 131
# Condition triggered at line 147
# Condition triggered at line 149
# Condition triggered at line 153
# Condition triggered at line 154
# Condition triggered at line 156
# Condition triggered at line 158
# Condition triggered at line 162
# Condition triggered at line 163
# Condition triggered at line 164
# Condition triggered at line 166
# Condition triggered at line 167
# Condition triggered at line 171
# Condition triggered at line 172
# Condition triggered at line 174
# Condition triggered at line 175
# Condition triggered at line 179
# Condition triggered at line 180
# Condition triggered at line 196
# Condition triggered at line 197
# Condition triggered at line 201
# Condition triggered at line 202
# [' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'AMS 5659 SOLUTION TREATED.', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ', ' ', 'BMS7-21 GRADE 2', ' ', ' ']
# ['-1A']
# ['-1A', '-101A']
# ['-1A', '-101A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A', '-115A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A', '-115A', 'BACN10JR3CFD']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A', '-115A', 'BACN10JR3CFD', '-8A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A', '-115A', 'BACN10JR3CFD', '-8A', '-116A']
# ['-1A', '-101A', 'BACN10JR3CFD', '-13A', '-113A', 'BACN10JR3CFD', '-14A', '-114A', 'BACN10JR3CFD', '-2A', '-102A', 'BACN10JR3CFD', '-41', '-35', 'BACN10YD1', '-43', '-37', '-47', '-45', '-39', '-47', '-5A', '-105A', 'BACN10JR3CFD', '-6A', '-106A', 'BACN10JR3CFD', '-7A', '-115A', 'BACN10JR3CFD', '-8A', '-116A', 'BACN10JR3CFD']
# Condition triggered at line 163
# Condition triggered at line 166
# Condition triggered at line 172
# Condition triggered at line 174
# Condition triggered at line 178
# Condition triggered at line 186
# Condition triggered at line 202
# Condition triggered at line 206
# Condition triggered at line 214
# Condition triggered at line 216
# Condition triggered at line 219
# Condition triggered at line 225
# Condition triggered at line 227
# Condition triggered at line 230
# Condition triggered at line 237
# Condition triggered at line 253
# Condition triggered at line 256
# Condition triggered at line 263
# Condition triggered at line 269
# Condition triggered at line 272
# Condition triggered at line 279
# Condition triggered at line 299
# Condition triggered at line 303
# Condition triggered at line 310
# Condition triggered at line 312
# Condition triggered at line 316
# Condition triggered at line 323
# Condition triggered at line 325
# Condition triggered at line 329
# Condition triggered at line 337
# Condition triggered at line 353
# Condition triggered at line 357
# Condition triggered at line 365
# [' ', 'QQ-A-250/12.', ' ', ' ', 'QQ-A-250/12', ' ', ' ', 'QQ-A-250/12', ' ', ' ', 'QQ-A-250/12.', ' ', ' ', 'QQ-A-250/12.', ' ', ' ', 'AMS4347.', ' ', ' ', 'AMS4347.', ' ', ' ', 'QQ-A-250/12.', ' ', ' ', 'QQ-A-250/12.', ' ', ' ', 'QQ-A-250/12.', ' ', ' ', 'QQ-A-250/12.', ' ']

# %% [markdown]
# # 2.2 結束

# %% [markdown]
# # 2.3開始

# %% [markdown]
# 將所有輸出的excel整合起來並依照MBOM格式填入

# %%
import pandas as pd
import glob
import os

def combine_excel_files(folder_path, output_file):
    # 要合併的Excel檔案路徑
    folder_path = os.path.join(folder_path, '*.xlsx')  # 使用資料夾路徑並匹配所有xlsx檔案

    # 讀取所有Excel檔案
    all_files = glob.glob(folder_path)

    # 創建一個空的DataFrame用於存儲合併後的資料
    combined_data = pd.DataFrame()

    # 迭代讀取每個Excel檔案並合併到combined_data中
    for file in all_files:
        df = pd.read_excel(file)  # 讀取Excel檔案
        combined_data = pd.concat([combined_data, df], ignore_index=True)  # 將資料合併到combined_data中

    # 寫入合併後的資料到新的Excel檔案中
    combined_data.to_excel(output_file, index=False)  # 檔案名稱為output_file，不包括索引

# 使用範例
input_folder = r'_PL\final_output'  # 替換成你的資料夾路徑
output_file = r'_PL\final_output\combine.xlsx'  # 合併後的Excel檔案名稱

combine_excel_files(input_folder, output_file)

# %%
import pandas as pd
import glob
import os
from openpyxl import load_workbook
from openpyxl.styles import Alignment, Font, PatternFill

def mbom_excel_files(folder_path, output_file):
    # 要合併的Excel檔案路徑
    folder_path = os.path.join(folder_path, '*.xlsx')  # 使用資料夾路徑並匹配所有xlsx檔案

    # 讀取所有Excel檔案
    all_files = glob.glob(folder_path)

    # 創建一個空的DataFrame用於存儲合併後的資料
    combined_data = pd.DataFrame()

    # 迭代讀取每個Excel檔案並合併到combined_data中
    for file in all_files:
        df = pd.read_excel(file)  # 讀取Excel檔案
        combined_data = pd.concat([combined_data, df], ignore_index=True)  # 將資料合併到combined_data中

    # 寫入合併後的資料到新的Excel檔案中
    combined_data.to_excel(output_file, index=False)  # 檔案名稱為output_file，不包括索引

    # 排版設定
    wb = load_workbook(output_file)
    sheet = wb.active
    target_row = 1
    last_col = sheet.max_column

    sheet.cell(row=1,column=1).value = ' '
    #將B欄填入NO
    sheet.cell(row=1, column=2).value = 'NO'

    # 設置Alignment物件，指定水平置中和自動換行
    alignment = Alignment(horizontal='center', wrapText=True)

    # 遍歷指定行的每一列，並將文字設置為置中和自動換行
    for col in range(1, last_col + 1):
        cell = sheet.cell(row=target_row, column=col)
        cell.alignment = alignment
    
    # 設定顏色與字形
    for col_index in range(1, last_col + 1):
        cell = sheet.cell(row=1, column=col_index)
        cell.fill = PatternFill(start_color="CCFFCC", end_color="CCFFCC", fill_type="solid")
        # 設定字形
        if isinstance(cell.value, str) and any('\u4e00' <= char <= '\u9fff' for char in cell.value):
            font = Font(name='Malgun Gothic', color='000000', bold=False)  # 設定要的中文字體
        else:
            font = Font(name='Calibri', color='000000', bold=False)  # 設定要的英文字體
        cell.font = font
    
    # 設定欄寬
    columns_to_adjust = ['L', 'M', 'P', 'Q']
    default_column_width = 30
    columns_to_adjust_1 = ['N', 'O']
    default_column_width_1 = 10

    for col_letter in columns_to_adjust:
        sheet.column_dimensions[col_letter].width = default_column_width
    for col_letter in columns_to_adjust_1:
        sheet.column_dimensions[col_letter].width = default_column_width_1

    # 儲存修改後的 Excel 檔案
    wb.save(output_file)

# 使用範例
input_folder = r'_PL\final_output'  # 替換成你的資料夾路徑
output_file = r'_PL\final_output\combine.xlsx'  # 合併後的Excel檔案名稱

mbom_excel_files(input_folder, output_file)

# %% [markdown]
# # 2.3結束
